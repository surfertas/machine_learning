# %%
import pandas as pd
import tensorflow as tf
from config import config

# %%
# Exercises from https://github.com/tdpetrou/Learn-Pandas/tree/master/Learn-Pandas/Selecting%20Subsets

# %%
#data_url = 'https://data.world/cityofchicago/food-inspections-map/workspace/file?filename=Food_Inspections_-_Map.csv'
#data_path = tf.contrib.keras.utils.get_file('Food_Inspections_-_Map', data_url)

# %%
home = config["home"]
df = pd.read_csv(home + '/Food_Inspections_-_Map.csv')

# %%
df.head()
# Out:
#                     DBA Name                      AKA Name  License #  \
# 0               DANY'S TACOS                  DANY'S TACOS  2511723.0
# 1      BILLY FOOD MARKET INC             BILLY FOOD MARKET  2517614.0
# 2  TAQUERIA HACIENDA TAPATIA     TAQUERIA HACIENDA TAPATIA  2517707.0
# 3     WILD GOOSE BAR & GRILL        WILD GOOSE BAR & GRILL    12475.0
# 4         PUBLICAN TAVERN K1  PUBLICAN TAVERN K1 (T3 MAIN)    34173.0
#
#   Facility Type           Risk               Address     City State      Zip  \
# 0    Restaurant  Risk 1 (High)  2857 S ST LOUIS AVE   CHICAGO    IL  60623.0
# 1           NaN   Risk 3 (Low)  3906 W ROOSEVELT RD   CHICAGO    IL  60624.0
# 2    Restaurant  Risk 1 (High)       4125 W 26TH ST   CHICAGO    IL  60623.0
# 3    Restaurant  Risk 1 (High)   4265 N LINCOLN AVE   CHICAGO    IL  60618.0
# 4    Restaurant  Risk 1 (High)    11601 W TOUHY AVE   CHICAGO    IL  60666.0
#
#   Inspection Date        Inspection Type    Results  \
# ...

# %% [markdown]
# ### Exercise 1

# %% [markdown]
# The current DataFrame has a simple `RangeIndex`. Let make the **`DBA Name`** column the index to make it more meaningful. Save the result to variable **`df`** and output the first five rows with the **`head`** method.

# %%
#df.index = df['DBA Name']
df = df.set_index('DBA Name')
df.head(5)
# Out:
#                                                AKA Name  License #  \
# DBA Name
# DANY'S TACOS                               DANY'S TACOS  2511723.0
# BILLY FOOD MARKET INC                 BILLY FOOD MARKET  2517614.0
# TAQUERIA HACIENDA TAPATIA     TAQUERIA HACIENDA TAPATIA  2517707.0
# WILD GOOSE BAR & GRILL           WILD GOOSE BAR & GRILL    12475.0
# PUBLICAN TAVERN K1         PUBLICAN TAVERN K1 (T3 MAIN)    34173.0
#
#                           Facility Type           Risk               Address  \
# DBA Name
# DANY'S TACOS                 Restaurant  Risk 1 (High)  2857 S ST LOUIS AVE
# BILLY FOOD MARKET INC               NaN   Risk 3 (Low)  3906 W ROOSEVELT RD
# TAQUERIA HACIENDA TAPATIA    Restaurant  Risk 1 (High)       4125 W 26TH ST
# WILD GOOSE BAR & GRILL       Restaurant  Risk 1 (High)   4265 N LINCOLN AVE
# PUBLICAN TAVERN K1           Restaurant  Risk 1 (High)    11601 W TOUHY AVE
#
#                               City State      Zip Inspection Date  \
# DBA Name
# ...

# %% [markdown]
# ### Exercise 2

# %% [markdown]
# Select the **`Risk`** column as a Series with just the indexing operator. Also select it with attribute access.

# %%
df["Risk"].head()
# Out:
# DBA Name
# DANY'S TACOS                 Risk 1 (High)
# BILLY FOOD MARKET INC         Risk 3 (Low)
# TAQUERIA HACIENDA TAPATIA    Risk 1 (High)
# WILD GOOSE BAR & GRILL       Risk 1 (High)
# PUBLICAN TAVERN K1           Risk 1 (High)
# Name: Risk, dtype: object

# %%
df.Risk.head()
# Out:
# DBA Name
# DANY'S TACOS                 Risk 1 (High)
# BILLY FOOD MARKET INC         Risk 3 (Low)
# TAQUERIA HACIENDA TAPATIA    Risk 1 (High)
# WILD GOOSE BAR & GRILL       Risk 1 (High)
# PUBLICAN TAVERN K1           Risk 1 (High)
# Name: Risk, dtype: object

# %% [markdown]
# ### Exercise 3

# %%
df[["Risk","Results"]].head()
# Out:
#                                     Risk    Results
# DBA Name
# DANY'S TACOS               Risk 1 (High)       Fail
# BILLY FOOD MARKET INC       Risk 3 (Low)  Not Ready
# TAQUERIA HACIENDA TAPATIA  Risk 1 (High)       Pass
# WILD GOOSE BAR & GRILL     Risk 1 (High)       Fail
# PUBLICAN TAVERN K1         Risk 1 (High)       Fail

# %% [markdown]
# ### Exercise 4

# %% [markdown]
# Select a single column as a DataFrame

# %%
df_col = df[["Risk"]]
df_col.head()
# Out:
#                                     Risk
# DBA Name
# DANY'S TACOS               Risk 1 (High)
# BILLY FOOD MARKET INC       Risk 3 (Low)
# TAQUERIA HACIENDA TAPATIA  Risk 1 (High)
# WILD GOOSE BAR & GRILL     Risk 1 (High)
# PUBLICAN TAVERN K1         Risk 1 (High)

# %% [markdown]
# ### Exercise 5

# %% [markdown]
# Select the row for the restaurant **`WILD GOOSE BAR & GRILL`**. What object is returned?

# %%
df.loc["WILD GOOSE BAR & GRILL"]
# Out:
#                                       AKA Name  License # Facility Type  \
# DBA Name
# WILD GOOSE BAR & GRILL  WILD GOOSE BAR & GRILL    12475.0    Restaurant
# WILD GOOSE BAR & GRILL  WILD GOOSE BAR & GRILL    12475.0    Restaurant
# WILD GOOSE BAR & GRILL  WILD GOOSE BAR & GRILL    12475.0    Restaurant
# WILD GOOSE BAR & GRILL  WILD GOOSE BAR & GRILL    12475.0    Restaurant
# WILD GOOSE BAR & GRILL  WILD GOOSE BAR & GRILL    12475.0    Restaurant
# WILD GOOSE BAR & GRILL  WILD GOOSE BAR & GRILL    12475.0    Restaurant
# WILD GOOSE BAR & GRILL  WILD GOOSE BAR & GRILL    12475.0    Restaurant
# WILD GOOSE BAR & GRILL  WILD GOOSE BAR & GRILL    12475.0    Restaurant
#
#                                  Risk              Address     City State  \
# DBA Name
# WILD GOOSE BAR & GRILL  Risk 1 (High)  4265 N LINCOLN AVE   CHICAGO    IL
# WILD GOOSE BAR & GRILL  Risk 1 (High)  4265 N LINCOLN AVE   CHICAGO    IL
# WILD GOOSE BAR & GRILL  Risk 1 (High)  4265 N LINCOLN AVE   CHICAGO    IL
# ...

# %% [markdown]
# ### Exercise 6

# %% [markdown]
# Select the rows for the restaurants **`WILD GOOSE BAR & GRILL`** and **`TAQUERIA HACIENDA TAPATIA`** along with columns **`Risk`** and **`Results`**.

# %%
df.loc[["WILD GOOSE BAR & GRILL", "TAQUERIA HACIENDA TAPATIA"], ["Risk", "Results"]]
# Out:
#                                     Risk Results
# DBA Name
# WILD GOOSE BAR & GRILL     Risk 1 (High)    Fail
# WILD GOOSE BAR & GRILL     Risk 1 (High)    Pass
# WILD GOOSE BAR & GRILL     Risk 1 (High)    Pass
# WILD GOOSE BAR & GRILL     Risk 1 (High)    Fail
# WILD GOOSE BAR & GRILL     Risk 1 (High)    Pass
# WILD GOOSE BAR & GRILL     Risk 1 (High)    Pass
# WILD GOOSE BAR & GRILL     Risk 1 (High)    Pass
# WILD GOOSE BAR & GRILL     Risk 1 (High)    Pass
# TAQUERIA HACIENDA TAPATIA  Risk 1 (High)    Pass
# TAQUERIA HACIENDA TAPATIA  Risk 1 (High)    Fail

# %% [markdown]
# ### Exercise 7

# %% [markdown]
# What is the risk of restaurant **`SCRUB A DUB`**?

# %%
df.loc["SCRUB A DUB", "Risk"]
# Out:
# 'Risk 2 (Medium)'

# %% [markdown]
# ### Exercise 8

# %% [markdown]
# Select every 3,000th restaurant from **`THRESHOLD SCHOOL`** to **`SCRUB A DUB`** and the columns from **`Inspection Type`** on to the end of the DataFrame.

# %%
df.loc[["THRESHOLD SCHOOL","SCRUB A DUB"],"Inspection Type":]
# Out:
#                  Inspection Type Results  \
# DBA Name
# THRESHOLD SCHOOL         Canvass    Pass
# THRESHOLD SCHOOL         Canvass    Pass
# THRESHOLD SCHOOL         Canvass    Pass
# THRESHOLD SCHOOL         Canvass    Pass
# THRESHOLD SCHOOL         Canvass    Pass
# THRESHOLD SCHOOL         Canvass    Pass
# THRESHOLD SCHOOL         Canvass    Pass
# THRESHOLD SCHOOL         Canvass    Pass
# SCRUB A DUB              Canvass    Pass
#
#                                                          Violations  \
# DBA Name
# THRESHOLD SCHOOL  38. VENTILATION: ROOMS AND EQUIPMENT VENTED AS...
# THRESHOLD SCHOOL  32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...
# THRESHOLD SCHOOL  38. VENTILATION: ROOMS AND EQUIPMENT VENTED AS...
# THRESHOLD SCHOOL  34. FLOORS: CONSTRUCTED PER CODE, CLEANED, GOO...
# THRESHOLD SCHOOL  37. TOILET ROOM DOORS SELF CLOSING: DRESSING R...
# THRESHOLD SCHOOL  33. FOOD AND NON-FOOD CONTACT EQUIPMENT UTENSI...
# ...

# %% [markdown]
# ### Exercise 9

# %% [markdown]
# Select all columns from the 500th restaurant to the 510th

# %%
df.iloc[500:510]
# Out:
#                                                   AKA Name  License #  \
# DBA Name
# PENINSULA CHICAGO,LLC                         MAIN KITCHEN  1091966.0
# VENEZUELAN BOWL GRILL LLC            VENEZUELAN BOWL GRILL  2424110.0
# JULIUS MEINL                                  JULIUS MEINL  2141409.0
# MEZQUITE EXPRESS # 2                  MEZQUITE EXPRESS # 2  2517585.0
# PORTILLO'S HOT DOGS                    PORTILLO'S HOT DOGS    39472.0
# SEE THRU CHINESE RESTAURANT    SEE THRU CHINESE RESTAURANT  1942299.0
# DENOVA FRESH MARKET                   MARTHA'S FOOD MARKET  2517805.0
# SOUTH LOOP MONTESSORI SCHOOL  SOUTH LOOP MONTESSORI SCHOOL  2517217.0
# LORETTO HOSPITAL                          LORETTO HOSPITAL  2204616.0
# MONTROSE DELI & FRUIT MARKET  MONTROSE DELI & FRUIT MARKET    20886.0
#
#                                       Facility Type           Risk  \
# DBA Name
# PENINSULA CHICAGO,LLC                    Restaurant  Risk 1 (High)
# ...

# %% [markdown]
# ### Exercise 10

# %% [markdown]
# Select restaurants 100, 1,000 and 10,000 along with columns 5, 3, and 1

# %%
df.iloc[[100,1000,10000],[5,3,1]]
# Out:
#                    City           Risk  License #
# DBA Name
# A-Z SALES INC.  CHICAGO  Risk 1 (High)  1490343.0
# ANONG INC.      CHICAGO  Risk 1 (High)  1942424.0
# ELVIA GAMA      CHICAGO  Risk 1 (High)  2423902.0

# %% [markdown]
# ### Exercise 11

# %% [markdown]
# Select the **`Risk`** column and save it to a Series

# %%
series = df[["Risk"]]
series.head()
# Out:
#                                     Risk
# DBA Name
# DANY'S TACOS               Risk 1 (High)
# BILLY FOOD MARKET INC       Risk 3 (Low)
# TAQUERIA HACIENDA TAPATIA  Risk 1 (High)
# WILD GOOSE BAR & GRILL     Risk 1 (High)
# PUBLICAN TAVERN K1         Risk 1 (High)

# %% [markdown]
# ### Exercise 12

# %% [markdown]
# Using the risk Series, select **`ARBYS`** and **`POPEYES FAMOUS FRIED CHICKEN`**

# %%
series.loc[["ARBYS","POPEYES FAMOUS FRIED CHICKEN"]].head()
# Out:
#                    Risk
# DBA Name
# ARBYS     Risk 1 (High)
# ARBYS     Risk 1 (High)
# ARBYS     Risk 1 (High)
# ARBYS     Risk 1 (High)
# ARBYS     Risk 1 (High)
